# %%
import torch

torch.__version__
# Out:
# '2.10.0+cu130'

# %% [markdown]
# # Базовые функции torch (тензоры)

# %%
t = torch.Tensor(3,5,2)

# %%
t = torch.empty(3, 5, 2) # равносильно предыдущей функции

# %%
t.dtype
# Out:
# torch.float32

# %%
t = torch.empty(3, 5, 2, dtype=torch.int32)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
torch.tensor([1])
# Out:
# tensor([1])

# %%
torch.tensor([1,2,0])
# Out:
# tensor([1, 2, 0])

# %%
torch.tensor([[1,2], [3,4], [5,6]])
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
torch.tensor([1, 2.0, 0])
# Out:
# tensor([1., 2., 0.])

# %%
torch.tensor([[1,2], [3,4], [5,6]], dtype=torch.float32)
# Out:
# tensor([[1., 2.],
#         [3., 4.],
#         [5., 6.]])

# %%
torch.IntTensor([1])
# Out:
# tensor([1], dtype=torch.int32)

# %%
torch.DoubleTensor(3, 2, 3, 5)
# Out:
# tensor([[[[3.1951e-311,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00]],
#
#          [[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00]]],
#
#
#         [[[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00]],
#
#          [[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00]]],
#
#
# ...

# %%
d = [[[1, 2, 3], [4, 5, 6]]]
t = torch.tensor(d, dtype=torch.float32)
t.type()
# Out:
# 'torch.FloatTensor'

# %%
t.dtype
# Out:
# torch.float32

# %%
t.dim() #кол-во осей
# Out:
# 3

# %%
t.size() # кол-во элементов на каждой оси
# Out:
# torch.Size([1, 2, 3])

# %%
t.shape # аналогичная команда
# Out:
# torch.Size([1, 2, 3])

# %%
import numpy as np
d_np = np.array([[[1, 2, 3], [4, 5, 6]]])
d_np
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]]])

# %%
t2 = torch.from_numpy(d_np) # перевод из numpy в tensor, берет те же характеристики что и в массиве numpy
t2
# Out:
# tensor([[[1, 2, 3],
#          [4, 5, 6]]])

# %%
t3 = torch.tensor(d_np, dtype=torch.float32) # перевод из numpy в tensor, преобразование, копирование данных из массива numpy
t3
# Out:
# tensor([[[1., 2., 3.],
#          [4., 5., 6.]]])

# %%
d = t2.numpy()
d
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]]])

# %%
t2.dtype
# Out:
# torch.int64

# %%
tf = t2.float()
tf
# Out:
# tensor([[[1., 2., 3.],
#          [4., 5., 6.]]])

# %% [markdown]
# ![image.png](attachment:image.png)
